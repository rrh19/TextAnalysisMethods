# %%
import numpy as np
import pandas as pd
#from pandas import DataFrame, Series
#import matplotlib.pyplot as plt

frame = pd.read_csv("Desktop/FakeNews/fake.csv")
frame.drop(['uuid', 'ord_in_thread','published','language','crawled'], axis=1, inplace=True)
frame.head(10)
# Out:
#                  author                                              title  \
# 0     Barracuda Brigade  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  reasoning with facts  Re: Why Did Attorney General Loretta Lynch Ple...
# 2     Barracuda Brigade  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3                Fed Up  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4                Fed Up  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
# 5     Barracuda Brigade  Hillary Goes Absolutely Berserk On Protester A...
# 6                Fed Up  BREAKING! NYPD Ready To Make Arrests In Weiner...
# 7                Fed Up  WOW! WHISTLEBLOWER TELLS CHILLING STORY Of Mas...
# 8                Fed Up  BREAKING: CLINTON CLEARED...Was This A Coordin...
# 9                Fed Up  EVIL HILLARY SUPPORTERS Yell "F*ck Trump"…Burn...
#
#                                                 text             site_url  \
# 0  Print They should pay all the back all the mon...  100percentfedup.com
# 1  Why Did Attorney General Loretta Lynch Plead T...  100percentfedup.com
# 2  Red State : \nFox News Sunday reported this mo...  100percentfedup.com
# 3  Email Kayla Mueller was a prisoner and torture...  100percentfedup.com
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  100percentfedup.com
# 5  Print Hillary goes absolutely berserk! She exp...  100percentfedup.com
# 6  BREAKING! NYPD Ready To Make Arrests In Weiner...  100percentfedup.com
# 7  BREAKING! NYPD Ready To Make Arrests In Weiner...  100percentfedup.com
# 8  \nLimbaugh said that the revelations in the Wi...  100percentfedup.com
# 9  Email \nThese people are sick and evil. They w...  100percentfedup.com
#
#   country  domain_rank                                       thread_title  \
# 0      US      25689.0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1      US      25689.0  Re: Why Did Attorney General Loretta Lynch Ple...
# 2      US      25689.0  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3      US      25689.0  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4      US      25689.0  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
# 5      US      25689.0  Hillary Goes Absolutely Berserk On Protester A...
# 6      US      25689.0  BREAKING! NYPD Ready To Make Arrests In Weiner...
# 7      US      25689.0  WOW! WHISTLEBLOWER TELLS CHILLING STORY Of Mas...
# 8      US      25689.0  BREAKING: CLINTON CLEARED...Was This A Coordin...
# 9      US      25689.0  EVIL HILLARY SUPPORTERS Yell "F*ck Trump"…Burn...
#
#    spam_score                                       main_img_url  \
# 0       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 1       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 2       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 3       0.068  http://100percentfedup.com/wp-content/uploads/...
# 4       0.865  http://100percentfedup.com/wp-content/uploads/...
# 5       0.000  http://bb4sp.com/wp-content/uploads/2016/11/Fu...
# 6       0.701  http://100percentfedup.com/wp-content/uploads/...
# 7       0.188  http://100percentfedup.com/wp-content/uploads/...
# 8       0.144  http://100percentfedup.com/wp-content/uploads/...
# 9       0.995  http://100percentfedup.com/wp-content/uploads/...
#
#    replies_count  participants_count  likes  comments  shares  type
# 0              0                   1      0         0       0  bias
# 1              0                   1      0         0       0  bias
# 2              0                   1      0         0       0  bias
# 3              0                   0      0         0       0  bias
# 4              0                   0      0         0       0  bias
# 5              0                   1      0         0       0  bias
# 6              0                   0      0         0       0  bias
# 7              0                   0      0         0       0  bias
# 8              0                   0      0         0       0  bias
# 9              0                   0      0         0       0  bias

# %%
print("Types and counts of stories")
df = frame.groupby(["type"]).size()
df
# Out:
# Types and counts of stories
# type
# bias            443
# bs            11492
# conspiracy      430
# fake             19
# hate            246
# junksci         102
# satire          146
# state           121
# dtype: int64

# %%
import numpy as np
import pandas as pd
#from pandas import DataFrame, Series
#import matplotlib.pyplot as plt

frame = pd.read_csv("Desktop/FakeNews/fake.csv")
frame.drop(['uuid', 'ord_in_thread','published','language','crawled'], axis=1, inplace=True)
df1 = frame.filter(items=['thread_title'])
df1 = df1.dropna()

# %%
#this variable is a list of titles, but some of the titles are strings and some are "nan" values from the dataframe. 
#filter out of the nan values to get the code below to work
titles = list(df1['thread_title'])

import pandas as pd
import requests 
import enchant

words = requests.get('http://ir.dcs.gla.ac.uk/resources/linguistic_utils/stop_words')
stoplist1 = words.text.split("\r\n")

from nltk.corpus import stopwords
stoplist2 = set(stopwords.words('english'))

stoplist1.extend(stoplist2)

fullstops = list(set(stoplist1))

def remove_stops(stoplist, wordlist):
    result = []
    for i in wordlist:
        if i not in stoplist:
                result.append(i)
    return result

def spellcheck(wordlist):
    result = []
    d = enchant.Dict("en_US")
    for i in wordlist:
        if d.check(i) or d.check(i.capitalize()):
            result.append(i)
         
    return result
def clean_text(list_of_texts):
    fully_cleaned =[]
    #normalize ocr errors
    for i in list_of_texts:
        #lowercase all
        ocr_lower = i.lower()
        #tokenize, remove punctuation and numbers, remove tabs, newlines, etc.
        ocr_cleaner = ocr_lower.replace("\n", " ").replace("\t", " ")
        ocr_tokens = ocr_cleaner.split(" ")
        
        no_numbers_or_punct = []
        for token in ocr_tokens:
            if token.isalpha():
                no_numbers_or_punct.append(token)
            else:
                
                new_token = ""
                for letter in token:
                    if letter.isalpha():
                        new_token += letter
                if new_token != "":
                    no_numbers_or_punct.append(new_token)  
        #almost_ready_before_spellcheck = remove_stops(fullstops, no_numbers_or_punct)
        #almost_ready = spellcheck(almost_ready_before_spellcheck)
        #from nltk.stem import WordNetLemmatizer
        #lemmatization
        #wordnet_lemmatizer = WordNetLemmatizer()
        #lemmas = []
        #for token in almost_ready:
        #    lemma = wordnet_lemmatizer.lemmatize(token)
        #    lemmas.append(lemma)
        
        #ready = [i for i in lemmas if len(i) > 2]
        #fully_cleaned.append(ready)
        fully_cleaned.append(no_numbers_or_punct)
    return fully_cleaned
ocr_cleaned = clean_text(titles)

print(ocr_cleaned)
# Out:
# [['muslims', 'busted', 'they', 'stole', 'millions', 'in', 'govt', 'benefits'], ['re', 'why', 'did', 'attorney', 'general', 'loretta', 'lynch', 'plead', 'the', 'fifth'], ['breaking', 'weiner', 'cooperating', 'with', 'fbi', 'on', 'hillary', 'email', 'investigation'], ['pin', 'drop', 'speech', 'by', 'father', 'of', 'daughter', 'kidnapped', 'and', 'killed', 'by', 'isis', 'i', 'have', 'voted', 'for', 'donald', 'j', 'trump', 'percentfedupcom'], ['fantastic', 'trumps', 'point', 'plan', 'to', 'reform', 'healthcare', 'begins', 'with', 'a', 'bombshell', 'percentfedupcom'], ['hillary', 'goes', 'absolutely', 'berserk', 'on', 'protester', 'at', 'rally', 'video'], ['breaking', 'nypd', 'ready', 'to', 'make', 'arrests', 'in', 'weiner', 'casehillary', 'visited', 'pedophile', 'island', 'at', 'least', 'timesmoney', 'laundering', 'underage', 'sex', 'payforplayproof', 'of', 'inappropriate', 'handling', 'classified', 'information', 'percentfedupcom'], ['wow', 'whistleblower', 'tells', 'chilling', 'story', 'of', 'massive', 'voter', 'fraud', 'trump', 'campaign', 'readies', 'lawsuit', 'against', 'fl', 'sec', 'of', 'elections', 'in', 'critical', 'district', 'video', 'percentfedupcom'], ['breaking', 'clinton', 'clearedwas', 'this', 'a', 'coordinated', 'last', 'minute', 'trick', 'to', 'energize', 'hillarys', 'base', 'percentfedupcom'], ['evil', 'hillary', 'supporters', 'yell', 'fck', 'trumpburn', 'truck', 'of', 'daddy', 'fishing', 'with', 'yr', 'son', 'over', 'of', 'trump', 'bumperstickers', 'video', 'percentfedupcom'], ['yikes', 'hillary', 'goes', 'off', 'the', 'railspulls', 'a', 'howard', 'dean', 'video'], ['say', 'goodbye', 'these', 'hollywood', 'celebs', 'threatened', 'to', 'leave', 'the', 'uslets', 'hold', 'them', 'to', 'it', 'percentfedupcom'], ['not', 'kidding', 'colleges', 'give', 'students', 'safe', 'spaces', 'to', 'cry', 'over', 'trump', 'winthreaten', 'students', 'over', 'protrump', 'chalkings'], ['boom', 'math', 'shows', 'trump', 'would', 'have', 'beaten', 'obama', 'in', 'romneyobama', 'election', 'percentfedupcom'], ['boom', 'this', 'is', 'how', 'president', 'reagan', 'handled', 'protesters', 'negotiate', 'what', 'is', 'there', 'to', 'negotiate', 'video', 'percentfedupcom'], ['trump', 'supporter', 'got', 'nuts', 'on', 'msnbc', 'reporter', 'covering', 'antitrump', 'rioters', 'video'], ['tomi', 'lahren', 'has', 'special', 'message', 'for', 'celebrities', 'who', 'said', 'theyd', 'move', 'to', 'canada', 'if', 'trump', 'won', 'video', 'percentfedupcom'], ['boycottcomedianrobert', 'deniro', 'wanted', 'to', 'punch', 'trump', 'in', 'the', 'facesupports', 'antitrump', 'riotersnow', 'wants', 'americans', 'to', 'support', 'his', 'new', 'movie', 'video'], ['hes', 'never', 'sold', 'an', 'original', 'painting', 'until', 'nowand', 'this', 'ones', 'going', 'in', 'the', 'white', 'house'], ['sorry', 'liberalsyou', 'can', 'stop', 'with', 'the', 'petitionshillary', 'did', 'not', 'win', 'the', 'popular', 'vote'], ['mark', 'cuban', 'in', 'the', 'event', 'donald', 'wins', 'i', 'have', 'no', 'doubt', 'the', 'market', 'tanksso', 'heres', 'what', 'really', 'happened', 'video', 'percentfedupcom'], ['trump', 'supporter', 'whose', 'brutal', 'beating', 'by', 'black', 'mob', 'was', 'caught', 'on', 'video', 'asks', 'what', 'happened', 'to', 'america', 'video'], ['wow', 'white', 'liberals', 'suggest', 'blacks', 'are', 'too', 'stupid', 'to', 'get', 'idscant', 'figure', 'out', 'how', 'to', 'use', 'internet', 'video'], ['lol', 'british', 'wife', 'of', 'lib', 'actor', 'who', 'said', 'there', 'will', 'never', 'be', 'a', 'president', 'donald', 'trumpwarns', 'americans', 'about', 'presidentelect', 'trump', 'video'], ['epic', 'tucker', 'carlson', 'demolishes', 'nyc', 'councilman', 'over', 'sanctuary', 'cities', 'video'], ['funny', 'snls', 'solution', 'to', 'democrat', 'election', 'denial', 'safe', 'space', 'for', 'everyone', 'video'], ['donald', 'trump', 'calls', 'meeting', 'with', 'pressdresses', 'down', 'real', 'fake', 'news', 'networks', 'everyone', 'at', 'cnn', 'is', 'a', 'liar ...
